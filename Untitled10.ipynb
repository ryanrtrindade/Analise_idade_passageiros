# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanrtrindade/Analise_idade_passageiros/blob/C%C3%B3digos/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
base = pd.read_csv('/content/drive/MyDrive/PYTHON/train.csv')

# %%
base2 = base.dropna(axis= 0, subset = 'Age')

# %%
plt.figure(figsize = (20,10))

plt.title('Idade de passageiros que sobreviveram x morreram')
plt.xlabel('Idade')
plt.ylabel('Frequencia')
plt.hist(base2[base2.Survived == 1].Age, color = 'Blue', label = 'Sobreviveu', alpha = 0.5, bins = 30, edgecolor = 'black', cumulative= True)
plt.hist(base2[base2.Survived == 0].Age, color = 'RED', label = 'Não sobreviveu', alpha = 0.5, bins = 30, edgecolor = 'black', cumulative = True)
plt.legend(loc = 'upper right')

# %%
plt.figure(figsize = (20,10))

media_sobreviventes = base2[base2.Survived == 1]['Age'].mean()
media_nao_sobreviventes = base2[base2.Survived == 0]['Age'].mean()

plt.bar('Sobreviveu', media_sobreviventes, color= 'Blue')
plt.bar('Não sobreviveu', media_nao_sobreviventes, color = 'Red')


plt.title('Média de idade dos sobreviventes x não sobreviventes')
plt.xlabel('Sobreviventes')
plt.ylabel('Média de sobreviventes')
plt.legend(loc = 'upper right')
# Out:
# /tmp/ipython-input-870454577.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc = 'upper right')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2497303877.py in <cell line: 0>()
# ----> 1 sns.barplot(base2['Survived'], base2['Age' ])
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
# Out:
# <Axes: >
